# %%
import sklearn
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
gameStats = pd.read_csv(r"C:\Users\joeho\Documents\2020stats.csv")
gameStats.head()
# Out:
#        gmDate seasonType   season  teamWins  teamLosses teamAbbr teamLoc  \
# 0  10/22/2019    Regular  2019-20         0           1      NOP    Away
# 1  10/22/2019    Regular  2019-20         0           1      LAL    Away
# 2  10/23/2019    Regular  2019-20         0           1      CHI    Away
# 3  10/23/2019    Regular  2019-20         1           0      DET    Away
# 4  10/23/2019    Regular  2019-20         0           1      CLE    Away
#
#   teamRslt  teamDayOff  teamPTS  ...  opptOrtg  opptDrtg  opptEDiff  \
# 0     Loss           0      122  ...     115.2     108.1        7.1
# 1     Loss           0      102  ...     117.5     107.0       10.5
# 2     Loss           0      125  ...     124.0     123.0        1.0
# 3      Win           0      119  ...     109.8     118.8       -9.0
# 4     Loss           0       85  ...      95.2      86.1        9.1
#
#    opptPlay%  opptAR  opptAST/TO  opptSTL/TO    opptPoss  opptPace  \
# ...

# %%
# for col in gameStats.columns: 
#     print(col)

# %%
x = np.array(gameStats.opptPace
        )
y = np.array(gameStats.opptPTS)
linreg = LinearRegression()
x = x.reshape(-1,1)
linreg.fit(x,y)
y_pred = linreg.predict(x)
plt.scatter(x,y)
plt.plot(x,y_pred, color ='red')
print('m',linreg.coef_)
print('b',linreg.intercept_)
print('r2',linreg.score(x,y))
plt.show
# Out:
# m [0.90676187]
# b 22.46195213762168
# r2 0.13517180267524054
# <function matplotlib.pyplot.show(close=None, block=None)>
